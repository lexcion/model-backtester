# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import ipywidgets as widgets
from IPython.display import display

# %%
odds_df=pd.read_csv("cleaned_all.csv")

# %%
with pd.option_context('display.max_rows', 5, 'display.max_columns', None): 
    display(odds_df)
# Out:
#        Period  Clock   Score  Home Odds  Handicap  Away Odds  \
# 0         4th  03:05  120-92       0.95     -26.5       0.80
# 1         4th  03:17  117-92       0.76     -23.5       1.00
# ...       ...    ...     ...        ...       ...        ...
# 332238    1st  11:11     2-0       0.80      -4.5       0.86
# 332239    1st  11:42     0-0       0.83      -4.5       0.83
#
#                   Status    Day Update              Type  home_team_name  \
# 0       Early, Live, Run  30-03  16:43  handicap_odds_q4  Denver Nuggets
# 1       Early, Live, Run  30-03  16:43  handicap_odds_q4  Denver Nuggets
# ...                  ...    ...    ...               ...             ...
# 332238  Early, Live, Run  29-10  20:12  handicap_odds_q2  Denver Nuggets
# 332239  Early, Live, Run  29-10  20:11  handicap_odds_q2  Denver Nuggets
#
#         home_team_score       away_team_name  away_team_score  \
# 0                   130  Cleveland Cavaliers              101
# 1                   130  Cleveland Cavaliers              101
# ...                 ...                  ...              ...
# 332238              110            Utah Jazz              102
# 332239              110            Utah Jazz              102
#
#                                   sport             match_date quarter_scores  \
# 0       National Basketball Association   3/31/2024 7:30:00 PM  (65-56,65-45)
# 1       National Basketball Association   3/31/2024 7:30:00 PM  (65-56,65-45)
# ...                                 ...                    ...            ...
# 332238  National Basketball Association  10/31/2023 1:00:00 AM  (58-45,52-57)
# 332239  National Basketball Association  10/31/2023 1:00:00 AM  (58-45,52-57)
#
#        Bookmaker                Total  Pregame Spread  handicap_home  \
# 0         Bet365      212, 218, 226.5            -4.5           0.87
# 1         Bet365      212, 218, 226.5            -4.5           0.87
# ...          ...                  ...             ...            ...
# 332238    Bet365  230.5, 225.5, 208.5            -9.0           0.91
# 332239    Bet365  230.5, 225.5, 208.5            -9.0           0.91
#
#         handicap_away  ml_home  ml_away  total_home  total_away  \
# 0                0.95     1.54     2.55        0.91        0.91
# 1                0.95     1.54     2.55        0.91        0.91
# ...               ...      ...      ...         ...         ...
# 332238           0.91     1.25     4.20        0.91        0.91
# 332239           0.91     1.25     4.20        0.91        0.91
#
#         H1 home score  H1 away score  H1 score difference  H1 score total  \
# 0                  65             56                    9             121
# 1                  65             56                    9             121
# ...               ...            ...                  ...             ...
# 332238             58             45                   13             103
# 332239             58             45                   13             103
#
#         Q4 home score  Q4 away score  Q4 score difference  Q4 score total  \
# 0                  65             45                   20             110
# 1                  65             45                   20             110
# ...               ...            ...                  ...             ...
# 332238             52             57                   -5             109
# 332239             52             57                   -5             109
#
#         Home Decimal Odds  Away Decimal Odds  Home Implied Winrate  \
# 0                    1.95               1.80              0.512821
# 1                    1.76               2.00              0.568182
# ...                   ...                ...                   ...
# 332238               1.80               1.86              0.555556
# 332239               1.83               1.83              0.546448
#
#         Away Implied Winrate  Score Home  Score Away  Score Diff  \
# 0                   0.555556         120          92          28
# 1                   0.500000         117          92          25
# ...                      ...         ...         ...         ...
# 332238              0.537634           2           0           2
# 332239              0.546448           0           0           0
#
#         Minutes Remaining Minutes Remaining Bucket  Spread Bucket  \
# 0                2.916667                      2-3       -7 to -3
# 1                2.716667                      2-3       -7 to -3
# ...                   ...                      ...            ...
# 332238          46.816667                    46-47  -11.5 to -7.5
# 332239          46.300000                    46-47  -11.5 to -7.5
#
#         Score Diff Bucket  score_diff_bucket minutes_remaining_bucket  \
# 0                      28                NaN                      NaN
# 1                      25                NaN                      NaN
# ...                   ...                ...                      ...
# 332238                  2                2.0                    46-47
# 332239                  0                0.0                    46-47
#
#         spread_bucket  win_rate_q1  loss_rate_q1  tie_rate_q1  win_rate_q2  \
# 0                 NaN          NaN           NaN          NaN          NaN
# 1                 NaN          NaN           NaN          NaN          NaN
# ...               ...          ...           ...          ...          ...
# 332238  -11.5 to -7.5        0.718         0.282        0.017        0.683
# 332239  -11.5 to -7.5        0.636         0.364        0.032        0.673
#
#         loss_rate_q2  tie_rate_q2  win_rate_q3  loss_rate_q3  tie_rate_q3  \
# 0                NaN          NaN          NaN           NaN          NaN
# 1                NaN          NaN          NaN           NaN          NaN
# ...              ...          ...          ...           ...          ...
# 332238         0.317        0.033        0.779         0.221        0.043
# 332239         0.327        0.032        0.728         0.272        0.029
#
#         Win Rate  Loss Rate  Tie Rate  win_rate_ot  loss_rate_ot  tie_rate_ot  \
# 0            NaN        NaN       NaN          NaN           NaN          NaN
# 1            NaN        NaN       NaN          NaN           NaN          NaN
# ...          ...        ...       ...          ...           ...          ...
# 332238     0.821      0.179     0.040          NaN           NaN          NaN
# 332239     0.772      0.228     0.047          NaN           NaN          NaN
#
#         optimal_handicap_ot  handicap_win_rates_ot  total_games_q1  wins_q1  \
# 0                       NaN                    NaN             NaN      NaN
# 1                       NaN                    NaN             NaN      NaN
# ...                     ...                    ...             ...      ...
# 332238                  NaN                    NaN           303.0    214.0
# 332239                  NaN                    NaN           341.0    210.0
#
#         ties_q1  losses_q1  optimal_handicap_q1  \
# 0           NaN        NaN                  NaN
# 1           NaN        NaN                  NaN
# ...         ...        ...                  ...
# 332238      5.0       84.0                 -4.5
# 332239     11.0      120.0                 -2.5
#
#                                     handicap_win_rates_q1  total_games_q2  \
# 0                                                     NaN             NaN
# 1                                                     NaN             NaN
# ...                                                   ...             ...
# 332238  {-8.5: 0.32, -8.0: 0.332, -7.5: 0.356, -7.0: 0...           303.0
# 332239  {-6.5: 0.326, -6.0: 0.339, -5.5: 0.367, -5.0: ...           341.0
#
#         wins_q2  ties_q2  losses_q2  optimal_handicap_q2  \
# 0           NaN      NaN        NaN                  NaN
# 1           NaN      NaN        NaN                  NaN
# ...         ...      ...        ...                  ...
# 332238    200.0     10.0       93.0                 -6.5
# 332239    222.0     11.0      108.0                 -5.5
#
#                                     handicap_win_rates_q2  total_games_q3  \
# 0                                                     NaN             NaN
# 1                                                     NaN             NaN
# ...                                                   ...             ...
# 332238  {-10.5: 0.366, -10.0: 0.376, -9.5: 0.393, -9.0...           303.0
# 332239  {-8.5: 0.402, -8.0: 0.418, -7.5: 0.44, -7.0: 0...           341.0
#
#         wins_q3  ties_q3  losses_q3  optimal_handicap_q3  \
# 0           NaN      NaN        NaN                  NaN
# 1           NaN      NaN        NaN                  NaN
# ...         ...      ...        ...                  ...
# 332238    226.0     13.0       64.0                 -9.5
# 332239    241.0     10.0       90.0                 -8.0
#
#                                     handicap_win_rates_q3  Sample Size  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# ...                                                   ...          ...
# 332238  {-13.5: 0.353, -13.0: 0.369, -12.5: 0.396, -12...        303.0
# 332239  {-11.5: 0.381, -11.0: 0.399, -10.5: 0.425, -10...        341.0
#
#         wins_q4  ties_q4  losses_q4  Optimal Handicap  \
# 0           NaN      NaN        NaN               NaN
# 1           NaN      NaN        NaN               NaN
# ...         ...      ...        ...               ...
# 332238    239.0     12.0       52.0             -10.0
# 332239    251.0     16.0       74.0              -7.5
#
#                                      Handicap Derivatives  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 332238  {-13.5: 0.399, -13.0: 0.406, -12.5: 0.416, -12...
# 332239  {-10.5: 0.408, -10.0: 0.425, -9.5: 0.449, -9.0...
#
#         score_diff_bucket_perm minutes_remaining_bucket_perm  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# ...                        ...                           ...
# 332238                     2.0                         46-47
# 332239                     0.0                         46-47
#
#        spread_bucket_perm  win_rate_q1_perm  loss_rate_q1_perm  \
# 0                     NaN               NaN                NaN
# 1                     NaN               NaN                NaN
# ...                   ...               ...                ...
# 332238      -11.5 to -7.5             0.718              0.282
# 332239      -11.5 to -7.5             0.636              0.364
#
#         tie_rate_q1_perm  win_rate_q2_perm  loss_rate_q2_perm  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 332238             0.017             0.683              0.317
# 332239             0.032             0.673              0.327
#
#         tie_rate_q2_perm  win_rate_q3_perm  loss_rate_q3_perm  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 332238             0.033             0.779              0.221
# 332239             0.032             0.728              0.272
#
#         tie_rate_q3_perm  Win Rate.1  Loss Rate.1  Tie Rate.1  \
# 0                    NaN         NaN          NaN         NaN
# 1                    NaN         NaN          NaN         NaN
# ...                  ...         ...          ...         ...
# 332238             0.043       0.821        0.179       0.040
# 332239             0.029       0.772        0.228       0.047
#
#         win_rate_ot_perm  loss_rate_ot_perm  tie_rate_ot_perm  \
# 0                    NaN                NaN               NaN
# 1                    NaN                NaN               NaN
# ...                  ...                ...               ...
# 332238               NaN                NaN               NaN
# 332239               NaN                NaN               NaN
#
#         optimal_handicap_ot_perm  handicap_win_rates_ot_perm  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# ...                          ...                         ...
# 332238                       NaN                         NaN
# 332239                       NaN                         NaN
#
#         total_games_q1_perm  wins_q1_perm  ties_q1_perm  losses_q1_perm  \
# 0                       NaN           NaN           NaN             NaN
# 1                       NaN           NaN           NaN             NaN
# ...                     ...           ...           ...             ...
# 332238                303.0         214.0           5.0            84.0
# 332239                341.0         210.0          11.0           120.0
#
#         optimal_handicap_q1_perm  \
# 0                            NaN
# 1                            NaN
# ...                          ...
# 332238                      -4.5
# 332239                      -2.5
#
#                                handicap_win_rates_q1_perm  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 332238  {-8.5: 0.32, -8.0: 0.332, -7.5: 0.356, -7.0: 0...
# 332239  {-6.5: 0.326, -6.0: 0.339, -5.5: 0.367, -5.0: ...
#
#         total_games_q2_perm  wins_q2_perm  ties_q2_perm  losses_q2_perm  \
# 0                       NaN           NaN           NaN             NaN
# 1                       NaN           NaN           NaN             NaN
# ...                     ...           ...           ...             ...
# 332238                303.0         200.0          10.0            93.0
# 332239                341.0         222.0          11.0           108.0
#
#         optimal_handicap_q2_perm  \
# 0                            NaN
# 1                            NaN
# ...                          ...
# 332238                      -6.5
# 332239                      -5.5
#
#                                handicap_win_rates_q2_perm  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 332238  {-10.5: 0.366, -10.0: 0.376, -9.5: 0.393, -9.0...
# 332239  {-8.5: 0.402, -8.0: 0.418, -7.5: 0.44, -7.0: 0...
#
#         total_games_q3_perm  wins_q3_perm  ties_q3_perm  losses_q3_perm  \
# 0                       NaN           NaN           NaN             NaN
# 1                       NaN           NaN           NaN             NaN
# ...                     ...           ...           ...             ...
# 332238                303.0         226.0          13.0            64.0
# 332239                341.0         241.0          10.0            90.0
#
#         optimal_handicap_q3_perm  \
# 0                            NaN
# 1                            NaN
# ...                          ...
# 332238                      -9.5
# 332239                      -8.0
#
#                                handicap_win_rates_q3_perm  Sample Size.1  \
# 0                                                     NaN            NaN
# 1                                                     NaN            NaN
# ...                                                   ...            ...
# 332238  {-13.5: 0.353, -13.0: 0.369, -12.5: 0.396, -12...          303.0
# 332239  {-11.5: 0.381, -11.0: 0.399, -10.5: 0.425, -10...          341.0
#
#         wins_q4_perm  ties_q4_perm  losses_q4_perm  Optimal Handicap.1  \
# 0                NaN           NaN             NaN                 NaN
# 1                NaN           NaN             NaN                 NaN
# ...              ...           ...             ...                 ...
# 332238         239.0          12.0            52.0               -10.0
# 332239         251.0          16.0            74.0                -7.5
#
#                                    Handicap Derivatives.1 Derivative Quarter  \
# 0                                                     NaN                NaN
# 1                                                     NaN                NaN
# ...                                                   ...                ...
# 332238  {-13.5: 0.399, -13.0: 0.406, -12.5: 0.416, -12...                 Q2
# 332239  {-10.5: 0.408, -10.0: 0.425, -9.5: 0.449, -9.0...                 Q2
#
#         Model Home Winrate  Model Away Winrate  Home EV  Away EV
# 0                      NaN                 NaN      NaN      NaN
# 1                      NaN                 NaN      NaN      NaN
# ...                    ...                 ...      ...      ...
# 332238               0.564               0.436  0.01520 -0.18904
# 332239               0.522               0.478 -0.04474 -0.12526
#
# [332240 rows x 138 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming odds_df is your DataFrame with the EV calculations

# Function to plot EV distributions and calculate statistics
def plot_ev_distribution(odds_df, ev_threshold=0.1):
    """
    Plots the distribution of EV values for Home and Away teams and calculates statistics.

    Parameters:
    - odds_df (DataFrame): DataFrame containing 'Home EV' and 'Away EV' columns.
    - ev_threshold (float): The EV threshold to highlight and calculate statistics. Default is 0.1.
    """
    # Calculate statistics for Home EV
    home_ev_mean = odds_df['Home EV'].mean()
    home_ev_std = odds_df['Home EV'].std()
    away_ev_mean = odds_df['Away EV'].mean()
    away_ev_std = odds_df['Away EV'].std()

    # Print statistics
    print(f"Home EV Mean: {home_ev_mean:.4f}, Home EV Std Dev: {home_ev_std:.4f}")
    print(f"Away EV Mean: {away_ev_mean:.4f}, Away EV Std Dev: {away_ev_std:.4f}")

    # Count EV values
    home_ev_ge_threshold = np.sum(odds_df['Home EV'] >= ev_threshold)
    home_ev_lt_threshold = np.sum(odds_df['Home EV'] < ev_threshold)
    away_ev_ge_threshold = np.sum(odds_df['Away EV'] >= ev_threshold)
    away_ev_lt_threshold = np.sum(odds_df['Away EV'] < ev_threshold)

    print(f"Home EV >= {ev_threshold}: {home_ev_ge_threshold}, Home EV < {ev_threshold}: {home_ev_lt_threshold}")
    print(f"Away EV >= {ev_threshold}: {away_ev_ge_threshold}, Away EV < {ev_threshold}: {away_ev_lt_threshold}")

    # Plotting Home EV
    plt.figure(figsize=(12, 6))
    n, bins, patches = plt.hist(odds_df['Home EV'].dropna(), bins=50, color='gray', edgecolor='black', alpha=0.7)
    plt.title('Distribution of Home EV')
    plt.xlabel('Home EV')
    plt.ylabel('Frequency')

    # Highlight bars where EV >= ev_threshold
    for patch, left_bin_edge in zip(patches, bins[:-1]):
        if left_bin_edge >= ev_threshold:
            patch.set_facecolor('green')
        else:
            patch.set_facecolor('red')

    plt.show()

    # Plotting Away EV
    plt.figure(figsize=(12, 6))
    n, bins, patches = plt.hist(odds_df['Away EV'].dropna(), bins=50, color='gray', edgecolor='black', alpha=0.7)
    plt.title('Distribution of Away EV')
    plt.xlabel('Away EV')
    plt.ylabel('Frequency')

    # Highlight bars where EV >= ev_threshold
    for patch, left_bin_edge in zip(patches, bins[:-1]):
        if left_bin_edge >= ev_threshold:
            patch.set_facecolor('green')
        else:
            patch.set_facecolor('red')

    plt.show()

# Example usage
'''plot_ev_distribution(odds_df, ev_threshold=0.15)'''
# Out:
# 'plot_ev_distribution(odds_df, ev_threshold=0.15)'

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# Function to calculate EV
def calculate_ev(implied_winrate, model_winrate):
    return model_winrate - implied_winrate

# Define the betting simulator function
def simulate_betting(
    df: pd.DataFrame,
    min_ev: float = 0.1,
    max_ev: float = 0.3,
    bet_amount: float = 2500,
    game_max: float = 5000,
    min_samplesize: int = 0,
    max_samplesize: int = 0,
    initial_bankroll: float = 100000,
    cooldown: int = 180,  # Cooldown in seconds
    q2=True,
    q4=True,
    handicap_range: tuple = (-10, 10),
    pregame_spread_range: tuple = (-15, 15),
    score_diff_range: tuple = (-20, 20),
    time_left_range: tuple = (0, 48)
) -> pd.DataFrame:
    """
    Simulates a betting strategy based on expected value and other parameters.

    Parameters:
    - df: DataFrame containing game and odds information.
    - min_ev: Minimum EV to consider a bet.
    - max_ev: Maximum EV to consider a bet.
    - bet_amount: Amount to bet per game.
    - game_max: Maximum cumulative bet allowed for a single game.
    - min_timeleft: Minimum time left in minutes for considering a bet.
    - max_timeleft: Maximum time left in minutes for considering a bet.
    - min_samplesize: Minimum sample size to consider for betting.
    - initial_bankroll: Starting bankroll for the betting simulation.
    - cooldown: Cooldown time in seconds after placing a bet on the same game and type.
    - q2: Whether to consider 2nd quarter bets.
    - q4: Whether to consider 4th quarter bets.
    - handicap_range: Tuple specifying the range of handicaps to consider.
    - pregame_spread_range: Tuple specifying the range of pregame spreads to consider.
    - score_diff_range: Tuple specifying the range of score differences to consider.
    - time_left_range: Tuple specifying the range of time left in the game to consider.

    Returns:
    - DataFrame containing details of all placed bets.
    """
    bankroll = initial_bankroll
    total_wagered = 0
    total_profit = 0
    q4profit = 0
    h1profit = 0
    win = 0
    loss = 0
    bet_count = 0
    # Dictionary to track cumulative bets for each game (home_team_name, away_team_name, match_date, Type)
    cumulative_bets = {}

    # Dictionary to track the last bet time for each game and type
    last_bet_time = {}

    # DataFrame to track each wager
    bets_data = []

    # List to track bankroll over time
    bankroll_over_time = [initial_bankroll]
    bankroll_over_time_h1 = [0]
    bankroll_over_time_q4 = [0]

    # Map periods to minutes remaining
    period_map = {'1st': 36, '2nd': 24, '3rd': 12, '4th': 0}
    
    # Set any empty value in 'Sample Size' to 0
    df['Sample Size'] = df['Sample Size'].fillna(0)

    # Iterate from the bottom to the top of the DataFrame with a progress bar
    for index, row in tqdm(df.iloc[::-1].iterrows(), total=df.shape[0], desc="Simulating Bets"):

        if row['Minutes Remaining'] < time_left_range[0] or row['Minutes Remaining'] > time_left_range[1] :
            continue
        
        
        if row['Handicap'] < handicap_range[0] or row['Handicap'] > handicap_range[1] :
            continue
        
         # Initialize score_diff based on Type
        if row['Type'] == "handicap_odds_q4" and q4==True:
            score_diff = row['Q4 score difference']+row['H1 score difference']
        
        elif row['Type'] == "handicap_odds_q2" and q2==True:
            score_diff = row['H1 score difference']
        else:
            continue

        
        # Calculate time left in the game
        minutes_left = period_map[row['Period']] + int(row['Clock'].split(':')[0])

        # Skip if sample size constraint is not met
        if row['Sample Size'] < min_samplesize:
            continue
        
        # Skip if sample size constraint is not met
        if row['Sample Size'] > max_samplesize:
            continue

        # Check if score difference is within the specified range
        if not score_diff_range[0] <= score_diff <= score_diff_range[1]:
            continue

        # Check if pregame spread is within the specified range
        if not pregame_spread_range[0] <= row['Pregame Spread'] <= pregame_spread_range[1]:
            continue

        # Construct a unique key for the game
        game_key = (row['home_team_name'], row['away_team_name'], row['match_date'], row['Type'])

        # Initialize cumulative bet amount for the game if not already present
        if game_key not in cumulative_bets:
            cumulative_bets[game_key] = 0

        # Check cooldown for the current game and type
        if game_key in last_bet_time:
            time_since_last_bet = (last_bet_time[game_key] - row['Minutes Remaining']*60)
            if time_since_last_bet < cooldown:
                continue  # Skip if still in cooldown period

        # Bet on Home Team if EV is within the specified range
        if min_ev < row['Home EV'] < max_ev:
            handicap = row['Handicap']
            pregamespread = row['Pregame Spread']
                    # Check if handicap is within the specified range
            if not handicap_range[0] <= handicap <= handicap_range[1]:
                continue
            if pregamespread < pregame_spread_range[0] or pregamespread > pregame_spread_range[1] :
                continue
            
            
            # Check if the cumulative bet for this game exceeds the maximum allowed bet
            if cumulative_bets[game_key] + bet_amount <= game_max:
                if score_diff + handicap > 0:
                    # Home team wins
                    profit = bet_amount * (row['Home Odds']) * 1.04
                    outcome = 'Win'
                    win+=1
                elif score_diff + handicap == 0:
                    profit = 0
                    outcome = 'Tie'
                else:
                    # Home team loses
                    profit = -bet_amount
                    outcome = 'Loss'
                    loss+=1
                
                
                # Update total profit, wagered, and bankroll
                total_profit += profit
                total_wagered += bet_amount
                bankroll += profit

                # Add bet details to bets_data
                bets_data.append({
                    'Wagered Team': row['home_team_name'],
                    'Home Team': row['home_team_name'],
                    'Away Team': row['away_team_name'],
                    'EV': row['Home EV'],
                    'Odds': row['Home Decimal Odds'],
                    'Final Score Difference': score_diff,
                    'Handicap': handicap,
                    'Pregame Handicap': row['Pregame Spread'],
                    'Current Period': row['Period'],
                    'Current Clock': row['Clock'],
                    'Current Score': row['Score'],
                    'Prediction Quarter': row['Derivative Quarter'],
                    'Final Score': row['quarter_scores'],
                    'Outcome': outcome,
                    'Profit': profit,
                    'New Bankroll': bankroll
                })

                # Update bankroll over time
                bankroll_over_time.append(bankroll)

                 # Update bankroll for specific quarters
                if row['Type'] == "handicap_odds_q4":
                    q4profit += profit
                    bankroll_over_time_q4.append(q4profit)
                elif row['Type'] == "handicap_odds_q2":
                    h1profit += profit
                    bankroll_over_time_h1.append(h1profit)

                # Update cumulative bet amount for the game
                cumulative_bets[game_key] += bet_amount

                # Update the last bet time for the game
                last_bet_time[game_key] = row['Minutes Remaining'] * 60

                bet_count += 1

        # Bet on Away Team if EV is within the specified range
        if min_ev < row['Away EV'] < max_ev:
            score_diff = -score_diff  # Invert score difference for away
            handicap = -row['Handicap']
            pregamespread = -row['Pregame Spread']

            if not handicap_range[0] <= handicap <= handicap_range[1]:
                continue
            if pregamespread < pregame_spread_range[0] or pregamespread > pregame_spread_range[1] :
                continue
            
            # Check if the cumulative bet for this game exceeds the maximum allowed bet
            if cumulative_bets[game_key] + bet_amount <= game_max:
                if score_diff + handicap > 0:
                    # Away team wins
                    profit = bet_amount * (row['Away Odds']) * 1.04
                    outcome = 'Win'
                    win+=1
                elif score_diff + handicap == 0:
                    profit = 0
                    outcome = 'Tie'
                else:
                    # Away team loses
                    profit = -bet_amount
                    outcome = 'Loss'
                    loss+=1
                
                #print(score_diff)  
                #print(handicap)
                #print(outcome)
                #print(score_diff+handicap)
                #print("")
                
                # Update total profit, wagered, and bankroll
                total_profit += profit
                total_wagered += bet_amount
                bankroll += profit
                
                # Add bet details to bets_data
                bets_data.append({
                    'Wagered Team': row['away_team_name'],
                    'Home Team': row['home_team_name'],
                    'Away Team': row['away_team_name'],
                    'EV': row['Away EV'],
                    'Odds': row['Away Decimal Odds'],
                    'Final Score Difference': score_diff,
                    'Handicap': handicap,
                    'Pregame Handicap': pregamespread,
                    'Current Period': row['Period'],
                    'Current Clock': row['Clock'],
                    'Current Score': row['Score'],
                    'Prediction Quarter': row['Derivative Quarter'],
                    'Final Score': row['quarter_scores'],
                    'Outcome': outcome,
                    'Profit': profit,
                    'New Bankroll': bankroll
                })

                # Update bankroll over time
                bankroll_over_time.append(bankroll)

                # Update bankroll for specific quarters
                if row['Type'] == "handicap_odds_q4":
                    q4profit += profit
                    bankroll_over_time_q4.append(q4profit)
                elif row['Type'] == "handicap_odds_q2":
                    h1profit += profit
                    bankroll_over_time_h1.append(h1profit)

                # Update cumulative bet amount for the game
                cumulative_bets[game_key] += bet_amount

                # Update the last bet time for the game
                last_bet_time[game_key] = row["Minutes Remaining"]

                bet_count += 1

    # Calculate ROI
    total_roi = (total_profit / total_wagered) * 100 if total_wagered != 0 else 0

    # Display Results
    print(f"Total Profit: ${total_profit:.2f}")
    print(f"Total Wagered: ${total_wagered:.2f}")
    print(f"Total Yield: {total_roi:.2f}%")
    print(f"Total Hitrate: {100*win/(win+loss):.2f}%")
    print(f"Sample Size: {bet_count}")
    print(f"Unique Games: {odds_df[['home_team_name', 'away_team_name', 'match_date']].drop_duplicates().shape[0]}")
    
    # Create a DataFrame for the bets
    bets_df = pd.DataFrame(bets_data)

    # Display the bets DataFrame
    print("\nBets Details:")
    print(bets_df.to_string(index=False))

    # Plot Bankroll Over Time
    plt.figure(figsize=(12, 6))
    plt.plot(bankroll_over_time, marker='o', linestyle='-', color='b')
    plt.title('Total Bankroll Over Time')
    plt.xlabel('Number of Bets')
    plt.ylabel('Bankroll ($)')
    plt.grid(True)
    plt.show()

    # Plot Bankroll for H1
    plt.figure(figsize=(12, 6))
    plt.plot(bankroll_over_time_h1, marker='o', linestyle='-', color='r')
    plt.title('Bankroll Over Time for H1 Bets')
    plt.xlabel('Number of Bets')
    plt.ylabel('Bankroll ($)')
    plt.grid(True)
    plt.show()

    # Plot Bankroll for Q4
    plt.figure(figsize=(12, 6))
    plt.plot(bankroll_over_time_q4, marker='o', linestyle='-', color='g')
    plt.title('Bankroll Over Time for Q4 Bets')
    plt.xlabel('Number of Bets')
    plt.ylabel('Bankroll ($)')
    plt.grid(True)
    plt.show()

    return bets_df
'''
# Randomly select half of the rows
odds_df_sample = odds_df.sample(frac=0.33, random_state=12)

# Run the betting simulation
bets_df = simulate_betting(
    df=odds_df_sample,
    min_ev=0.175,
    max_ev=1,
    bet_amount=5000,
    game_max=15000,
    min_samplesize=10,
    max_samplesize=100000,
    initial_bankroll=100000,
    cooldown=120,
    q4=True,
    q2=False,
    handicap_range=(-30, 30),
    pregame_spread_range=(-30, 30),
    time_left_range=(0, 40)
)'''
# Out:
# '\n# Randomly select half of the rows\nodds_df_sample = odds_df.sample(frac=0.33, random_state=12)\n\n# Run the betting simulation\nbets_df = simulate_betting(\n    df=odds_df_sample,\n    min_ev=0.175,\n    max_ev=1,\n    bet_amount=5000,\n    game_max=15000,\n    min_samplesize=10,\n    max_samplesize=100000,\n    initial_bankroll=100000,\n    cooldown=120,\n    q4=True,\n    q2=False,\n    handicap_range=(-30, 30),\n    pregame_spread_range=(-30, 30),\n    time_left_range=(0, 40)\n)'

# %%
# Create widgets
ev_threshold_slider = widgets.FloatSlider(
    value=0.15,
    min=0.0,
    max=1.0,
    step=0.01,
    description='EV Threshold:',
    continuous_update=False
)

min_ev_slider = widgets.FloatSlider(
    value=0.175,
    min=0.0,
    max=1.0,
    step=0.01,
    description='Min EV:',
    continuous_update=False
)

max_ev_slider = widgets.FloatSlider(
    value=1.0,
    min=0.0,
    max=2.0,
    step=0.01,
    description='Max EV:',
    continuous_update=False
)

bet_amount_slider = widgets.IntSlider(
    value=5000,
    min=100,
    max=10000,
    step=100,
    description='Bet Amount:',
    continuous_update=False
)

game_max_slider = widgets.IntSlider(
    value=15000,
    min=1000,
    max=30000,
    step=500,
    description='Game Max:',
    continuous_update=False
)

initial_bankroll_slider = widgets.IntSlider(
    value=100000,
    min=1000,
    max=1000000,
    step=5000,
    description='Initial Bankroll:',
    continuous_update=False
)

cooldown_slider = widgets.IntSlider(
    value=120,
    min=0,
    max=600,
    step=10,
    description='Cooldown (s):',
    continuous_update=False
)

q2_toggle = widgets.Checkbox(
    value=False,
    description='Consider Q2 Bets',
    disabled=False
)

q4_toggle = widgets.Checkbox(
    value=True,
    description='Consider Q4 Bets',
    disabled=False
)

# %%
def run_simulation(ev_threshold, min_ev, max_ev, bet_amount, game_max, initial_bankroll, cooldown, q2, q4):
    # Plot EV Distribution
    plot_ev_distribution(odds_df, ev_threshold)
    
    # Simulate Betting
    odds_df_sample = odds_df.sample(frac=0.33, random_state=12)
    bets_df = simulate_betting(
        df=odds_df_sample,
        min_ev=min_ev,
        max_ev=max_ev,
        bet_amount=bet_amount,
        game_max=game_max,
        min_samplesize=10,
        max_samplesize=100000,
        initial_bankroll=initial_bankroll,
        cooldown=cooldown,
        q4=q4,
        q2=q2,
        handicap_range=(-30, 30),
        pregame_spread_range=(-30, 30),
        time_left_range=(0, 40)
    )
    return

# %%
# Link widgets to the simulation function
out = widgets.interactive_output(run_simulation, {
    'ev_threshold': ev_threshold_slider,
    'min_ev': min_ev_slider,
    'max_ev': max_ev_slider,
    'bet_amount': bet_amount_slider,
    'game_max': game_max_slider,
    'initial_bankroll': initial_bankroll_slider,
    'cooldown': cooldown_slider,
    'q2': q2_toggle,
    'q4': q4_toggle
})

# %%
# Display widgets and output
ui = widgets.VBox([
    ev_threshold_slider,
    min_ev_slider,
    max_ev_slider,
    bet_amount_slider,
    game_max_slider,
    initial_bankroll_slider,
    cooldown_slider,
    q2_toggle,
    q4_toggle
])

display(ui, out)

# %%
voila betting_simulator.ipynb
